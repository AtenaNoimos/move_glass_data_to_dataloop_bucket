# %%
cd ../..
# Out:
# /Users/atenafadaei/Documents/codes/repository/core

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from notebooks.dataloop_data_prep.prep_dataloop_dataset import prep_dataloop_dataset

# %% [markdown]
# 1. Change the `target_garage`in the config to your desired garage.
# 2. Specify the `data_type`
# 3. specify the time period if you want

# %%
config_path = "notebooks/dataloop_data_prep/config.yaml"
createdAt_lower_limit= "2023-11-15 07:35:39.829978"
#createdAt_upper_limit = "2023-12-14 07:35:39.829978"
df = prep_dataloop_dataset(config_path=config_path,
                           createdAt_lower_limit=createdAt_lower_limit)
# Out:
# glass_evaluation.mart_app_glass_pilot_garages_cases
# ['glass_damage_close_up', 'glass_damage_close_up_diff_angle', 'glass_damage_close_upp_more', 'glass_damage_close_upp_more2', 'glass_damage_close_upp_more3', 'glass_damage_close_upp_more4', 'glass_damage_close_upp_more5', 'glass_damage_close_upp_more6', 'detail1-substep0', 'detail2-substep0', 'detail1-substep1', 'detail1-substep2', 'detail2-substep1', 'detail2-substep2', 'detail1-substep3', 'detail2-substep3', 'detail1-substep4', 'detail2-substep4']
# Total number of detail images for pilot_garages:  155
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# Image file already exists, skip coping file...
# ...
